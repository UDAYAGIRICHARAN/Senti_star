# %%
#AUTO MATED REGRESSION....!!

# %%
# !pip install pycaret

# %%
import pandas as pd
data=pd.read_csv('/content/ted_vectors.csv')
data.head()
# Out:
#    Unnamed: 0   views         F1  ...   vectors  vectors2  vectors3
# 0           0  169192     family  ... -0.160188 -0.169253  0.285615
# 1           1  375499       race  ... -0.369320 -0.255276 -0.486187
# 2           2   54900   humanity  ...  0.483306  0.244752  0.009500
# 3           3  294357  education  ... -0.268659  0.129196 -0.331198
# 4           4  124683     TED-Ed  ...  0.129196 -0.331198 -0.268659
#
# [5 rows x 8 columns]

# %%
data.tail()
# Out:
#       Unnamed: 0    views   vectors  vectors2  vectors3
# 1062        1062  2406187  0.000362 -0.425674  0.404535
# 1063        1063  1524699  0.195115  0.285615  0.353298
# 1064        1064   916584  0.148625  0.285615 -0.201453
# 1065        1065  1341636  0.428544 -0.172111 -0.253132
# 1066        1066  1062108  0.166989 -0.300283  0.148625

# %%
data.drop(['F1','F2','F3'],inplace=True,axis=1)

# %%
from pycaret.regression import *
clf1 = setup(data =data, target = 'views')
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_c2810d40_c2ba_11ea_8981_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c2810d40_c2ba_11ea_8981_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c2810d40_c2ba_11ea_8981_0242ac1c0002row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_c2810d40_c2ba_11ea_8981_0242ac1c0002row0_col1" class="data row0 col1" >4937</td>
#             </tr>
#             <tr>
#                         <th id="T_c2810d40_c2ba_11ea_8981_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c2810d40_c2ba_11ea_8981_0242ac1c0002row1_col0" class="data row1 col0" >Transform Target </td>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_d80841ba_c2ba_11ea_8981_0242ac1c0002 th {
#           text-align: left;
#     }    #T_d80841ba_c2ba_11ea_8981_0242ac1c0002row0_col0 {
#             text-align:  left;
#         }    #T_d80841ba_c2ba_11ea_8981_0242ac1c0002row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_d80841ba_c2ba_11ea_8981_0242ac1c0002row0_col2 {
#             : ;
#             text-align:  left;
#         }    #T_d80841ba_c2ba_11ea_8981_0242ac1c0002row0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_d80841ba_c2ba_11ea_8981_0242ac1c0002row0_col4 {
#             text-align:  left;
#         }    #T_d80841ba_c2ba_11ea_8981_0242ac1c0002row0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_d80841ba_c2ba_11ea_8981_0242ac1c0002row0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_d80841ba_c2ba_11ea_8981_0242ac1c0002row1_col0 {
# ...

# %%
BR = create_model('br')
# Out:
#                MAE           MSE          RMSE      R2   RMSLE    MAPE
# 0     7.671320e+05  8.305134e+11  9.113251e+05 -0.1200  1.3607  4.8572
# 1     7.511876e+05  1.096876e+12  1.047318e+06 -0.0029  1.0832  2.6248
# 2     6.719106e+05  8.955507e+11  9.463354e+05 -0.0002  0.9023  1.3304
# 3     8.747170e+05  2.115318e+12  1.454413e+06 -0.0089  1.1715  2.8413
# 4     1.010751e+06  7.081643e+12  2.661136e+06 -0.0128  0.9406  1.3142
# 5     7.890578e+05  1.705800e+12  1.306063e+06 -0.0105  1.3281  5.1431
# 6     5.710038e+05  5.367421e+11  7.326269e+05 -0.0264  0.9394  1.9794
# 7     8.180082e+05  1.130584e+12  1.063289e+06 -0.0002  1.2849  4.8355
# 8     8.734461e+05  1.506495e+12  1.227394e+06 -0.0213  1.1316  2.2027
# 9     1.098692e+06  3.941253e+12  1.985259e+06 -0.0376  1.3706  5.8368
# Mean  8.225907e+05  2.084078e+12  1.333516e+06 -0.0241  1.1513  3.2965
# SD    1.456914e+05  1.901694e+12  5.530034e+05  0.0340  0.1726  1.6141

# %%
tuned_BR= tune_model('br')
# Out:
#                MAE           MSE          RMSE      R2   RMSLE    MAPE
# 0     7.671320e+05  8.305134e+11  9.113251e+05 -0.1200  1.3607  4.8572
# 1     7.511876e+05  1.096876e+12  1.047318e+06 -0.0029  1.0832  2.6248
# 2     6.719106e+05  8.955507e+11  9.463354e+05 -0.0002  0.9023  1.3304
# 3     8.747170e+05  2.115318e+12  1.454413e+06 -0.0089  1.1715  2.8413
# 4     1.010751e+06  7.081643e+12  2.661136e+06 -0.0128  0.9406  1.3142
# 5     7.890578e+05  1.705800e+12  1.306063e+06 -0.0105  1.3281  5.1431
# 6     5.710038e+05  5.367421e+11  7.326269e+05 -0.0264  0.9394  1.9794
# 7     8.180082e+05  1.130584e+12  1.063289e+06 -0.0002  1.2849  4.8355
# 8     8.734461e+05  1.506495e+12  1.227394e+06 -0.0213  1.1316  2.2027
# 9     1.098692e+06  3.941253e+12  1.985259e+06 -0.0376  1.3706  5.8368
# Mean  8.225907e+05  2.084078e+12  1.333516e+06 -0.0241  1.1513  3.2965
# SD    1.456914e+05  1.901694e+12  5.530034e+05  0.0340  0.1726  1.6141

# %%
tuned_BR.predict([[0.166989,	-0.300283	,0.148625]])
# Out:
# array([1412490.05764075])

# %%
tuned_BR.predict([[0.148625,	0.285615	,-0.201453]])
# Out:
# array([1412490.05764075])

# %%
import pandas as pd
data_unseen = pd.read_csv('test.csv')


# generate predictions on unseen data
predictions = predict_model(tuned_xgboost, data = data_unseen)

# %%
print(predictions)
